# %%
import pandas as pd
import seaborn as sb
import datetime


mass_shootings = pd.read_csv('assets/mass_shoot_data.csv')
mass_shootings['Incident Date'] = pd.to_datetime(mass_shootings['Incident Date']).dt.strftime("%m-%d-%y")
mass_shootings.head(20)


mass_shoot_chart = sb.scatterplot(data=mass_shootings.head(15), y="# Killed", x="Incident Date")
