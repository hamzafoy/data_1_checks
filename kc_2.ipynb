# %%
import pandas as pd
import seaborn as sb
import datetime


mass_shootings = pd.read_csv('assets/mass_shoot_data.csv')
mass_shootings.head(10)


mass_shoot_chart = sb.scatterplot(data=mass_shootings, y="# Killed", x="Incident Date")
