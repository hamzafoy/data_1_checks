# %%
import pandas as pd
import seaborn as sb

mass_shootings = pd.read_csv('assets/mass_shoot_data.csv')
mass_shootings.head(10)
# Out:
#    Incident ID     Incident Date           State City Or County  \
# 0      2445939  October 25, 2022  North Carolina     Greensboro
# 1      2443879  October 24, 2022        Missouri    Saint Louis
# 2      2443849  October 24, 2022        Illinois        Chicago
# 3      2443627  October 23, 2022           Texas    Brownsville
# 4      2443194  October 23, 2022        Illinois        Chicago
# 5      2443276  October 23, 2022       Wisconsin      Milwaukee
# 6      2442695  October 22, 2022       Wisconsin      Milwaukee
# 7      2443257  October 22, 2022  North Carolina         Oxford
# 8      2443231  October 22, 2022         Arizona        Phoenix
# 9      2443287  October 22, 2022         Georgia        Cordele
#
#                             Address  # Killed  # Injured  Operations
# 0            900 block of Circle Dr         2          4         NaN
# 1          3125 S Kingshighway Blvd         3          4         NaN
# ...
